# %%
import os
import cv2
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, Activation, Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D
from keras.models import load_model

folder_path = './train_frame/'
classes = ['ab','n']
num_classes = len(classes)

image_w = 68 #원래 사이즈를 나눈값
image_h = 24

X = [] #정상, 비정상의 픽셀데이터값
Y = [] #label

for index, cla in enumerate(classes):
    label = [0 for i in range(num_classes)]
    label[index] = 1
    image_dir = folder_path + cla + '/' 
    for top, dir, f in os.walk(image_dir): # os를 사용해서 사진을 리스트로 바꾼다
        for filename in f:
            print(image_dir+filename)
            img = cv2.imread(image_dir + filename)
            img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h / img.shape[0])
            X.append(img/256)
            Y.append(label)
X = np.array(X)
Y = np.array(Y)
print(X.shape)

model = Sequential()
model.add(Convolution2D(16, 3, 3, border_mode='same', activation='relu', input_shape=X.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, batch_size=16, nb_epoch=5)
model.summary()

def testcut(path):
    image_w = 68
    image_h = 24
    img = cv2.imread(path)
    img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h/img.shape[0])
    return img/256
src = []
name = []
test = []
image_dir = './test_n1/'
for file in os.listdir(image_dir):
    src.append(image_dir + file)
    name.append(file)
    test.append(testcut(image_dir+file))
src = np.array(src)
name = np.array(name)
test = np.array(test)
print(test)

predict = model.predict_classes(test)

# for i in range(len(test)):
#     print(name[i] + ' predict : ' + str(classes[predict[i]]))

# list = []
# for in range(len(test)):
#         list = classes[predict[i]]
#         list.append(list)
        
# data = {'n1': list}

countlist=[]
for i in range(len(test)):
    print(name[i] + ' predict : ' + str(classes[predict[i]]))
    countlist.append(예측결과)
    total = countlist.count(n) + countlist.count(ab)
    print('이석증 확률 : ' + countlist.count(n)/total + "%")
# Out:
# Using TensorFlow backend.
# ./train_frame/ab/a1 107.jpg
# ./train_frame/ab/a1 108.jpg
# ./train_frame/ab/a1 109.jpg
# ./train_frame/ab/a1 110.jpg
# ./train_frame/ab/a1 111.jpg
# ./train_frame/ab/a1 112.jpg
# ./train_frame/ab/a1 113.jpg
# ./train_frame/ab/a1 114.jpg
# ./train_frame/ab/a1 115.jpg
# ./train_frame/ab/a1 136.jpg
# ./train_frame/ab/a1 137.jpg
# ./train_frame/ab/a1 138.jpg
# ./train_frame/ab/a1 139.jpg
# ./train_frame/ab/a1 14.jpg
# ./train_frame/ab/a1 140.jpg
# ./train_frame/ab/a1 141.jpg
# ./train_frame/ab/a1 142.jpg
# ./train_frame/ab/a1 143.jpg
# ./train_frame/ab/a1 144.jpg
# ./train_frame/ab/a1 15.jpg
# ./train_frame/ab/a1 16.jpg
# ./train_frame/ab/a1 164.jpg
# ./train_frame/ab/a1 165.jpg
# ./train_frame/ab/a1 166.jpg
# ./train_frame/ab/a1 167.jpg
# ./train_frame/ab/a1 168.jpg
# ./train_frame/ab/a1 169.jpg
# ./train_frame/ab/a1 17.jpg
# ./train_frame/ab/a1 18.jpg
# ./train_frame/ab/a1 186.jpg
# ./train_frame/ab/a1 187.jpg
# ./train_frame/ab/a1 188.jpg
# ...

# %%
list_n1 = []
for i in range(len(test)):
        classes[predict[i]]
        list_n1.append(classes[predict[i]])

# %%
a = pd.Series(list_n1, name='n1')

# %%
import os
import cv2
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, Activation, Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D
from keras.models import load_model

folder_path = './train_frame/'
classes = ['ab','n']
num_classes = len(classes)

image_w = 68 #원래 사이즈를 나눈값
image_h = 24

X = [] #정상, 비정상의 픽셀데이터값
Y = [] #label

for index, cla in enumerate(classes):
    label = [0 for i in range(num_classes)]
    label[index] = 1
    image_dir = folder_path + cla + '/' 
    for top, dir, f in os.walk(image_dir): # os를 사용해서 사진을 리스트로 바꾼다
        for filename in f:
            print(image_dir+filename)
            img = cv2.imread(image_dir + filename)
            img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h / img.shape[0])
            X.append(img/256)
            Y.append(label)
X = np.array(X)
Y = np.array(Y)
print(X.shape)

model = Sequential()
model.add(Convolution2D(16, 3, 3, border_mode='same', activation='relu', input_shape=X.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, batch_size=16, nb_epoch=5)
model.summary()

def testcut(path):
    image_w = 68
    image_h = 24
    img = cv2.imread(path)
    img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h/img.shape[0])
    return img/256
src = []
name = []
test = []
image_dir = './test_a8/'
for file in os.listdir(image_dir):
    src.append(image_dir + file)
    name.append(file)
    test.append(testcut(image_dir+file))
src = np.array(src)
name = np.array(name)
test = np.array(test)
print(test)

predict = model.predict_classes(test)

# for i in range(len(test)):
#     print(name[i] + ' predict : ' + str(classes[predict[i]]))

# list = []
# for in range(len(test)):
#         list = classes[predict[i]]
#         list.append(list)
        
# data = {'n1': list}
# Out:
# ./train_frame/ab/a1 107.jpg
# ./train_frame/ab/a1 108.jpg
# ./train_frame/ab/a1 109.jpg
# ./train_frame/ab/a1 110.jpg
# ./train_frame/ab/a1 111.jpg
# ./train_frame/ab/a1 112.jpg
# ./train_frame/ab/a1 113.jpg
# ./train_frame/ab/a1 114.jpg
# ./train_frame/ab/a1 115.jpg
# ./train_frame/ab/a1 136.jpg
# ./train_frame/ab/a1 137.jpg
# ./train_frame/ab/a1 138.jpg
# ./train_frame/ab/a1 139.jpg
# ./train_frame/ab/a1 14.jpg
# ./train_frame/ab/a1 140.jpg
# ./train_frame/ab/a1 141.jpg
# ./train_frame/ab/a1 142.jpg
# ./train_frame/ab/a1 143.jpg
# ./train_frame/ab/a1 144.jpg
# ./train_frame/ab/a1 15.jpg
# ./train_frame/ab/a1 16.jpg
# ./train_frame/ab/a1 164.jpg
# ./train_frame/ab/a1 165.jpg
# ./train_frame/ab/a1 166.jpg
# ./train_frame/ab/a1 167.jpg
# ./train_frame/ab/a1 168.jpg
# ./train_frame/ab/a1 169.jpg
# ./train_frame/ab/a1 17.jpg
# ./train_frame/ab/a1 18.jpg
# ./train_frame/ab/a1 186.jpg
# ./train_frame/ab/a1 187.jpg
# ./train_frame/ab/a1 188.jpg
# ./train_frame/ab/a1 19.jpg
# ...

# %%
list_a8 = []
for i in range(len(test)):
        classes[predict[i]]
        list_a8.append(classes[predict[i]])

# %%
b = pd.Series(list_a8[:130], name='a8')

# %%
import os
import cv2
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, Activation, Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D
from keras.models import load_model

folder_path = './train_frame/'
classes = ['ab','n']
num_classes = len(classes)

image_w = 68 #원래 사이즈를 나눈값
image_h = 24

X = [] #정상, 비정상의 픽셀데이터값
Y = [] #label

for index, cla in enumerate(classes):
    label = [0 for i in range(num_classes)]
    label[index] = 1
    image_dir = folder_path + cla + '/' 
    for top, dir, f in os.walk(image_dir): # os를 사용해서 사진을 리스트로 바꾼다
        for filename in f:
            print(image_dir+filename)
            img = cv2.imread(image_dir + filename)
            img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h / img.shape[0])
            X.append(img/256)
            Y.append(label)
X = np.array(X)
Y = np.array(Y)
print(X.shape)

model = Sequential()
model.add(Convolution2D(16, 3, 3, border_mode='same', activation='relu', input_shape=X.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, batch_size=16, nb_epoch=5)
model.summary()

def testcut(path):
    image_w = 68
    image_h = 24
    img = cv2.imread(path)
    img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h/img.shape[0])
    return img/256
src = []
name = []
test = []
image_dir = './test_ap1.3R/'
for file in os.listdir(image_dir):
    src.append(image_dir + file)
    name.append(file)
    test.append(testcut(image_dir+file))
src = np.array(src)
name = np.array(name)
test = np.array(test)
print(test)

predict = model.predict_classes(test)

# for i in range(len(test)):
#     print(name[i] + ' predict : ' + str(classes[predict[i]]))

list_ap1_3R = []
for i in range(len(test)):
        classes[predict[i]]
        list_ap1_3R.append(classes[predict[i]])
# Out:
# ./train_frame/ab/a1 107.jpg
# ./train_frame/ab/a1 108.jpg
# ./train_frame/ab/a1 109.jpg
# ./train_frame/ab/a1 110.jpg
# ./train_frame/ab/a1 111.jpg
# ./train_frame/ab/a1 112.jpg
# ./train_frame/ab/a1 113.jpg
# ./train_frame/ab/a1 114.jpg
# ./train_frame/ab/a1 115.jpg
# ./train_frame/ab/a1 136.jpg
# ./train_frame/ab/a1 137.jpg
# ./train_frame/ab/a1 138.jpg
# ./train_frame/ab/a1 139.jpg
# ./train_frame/ab/a1 14.jpg
# ./train_frame/ab/a1 140.jpg
# ./train_frame/ab/a1 141.jpg
# ./train_frame/ab/a1 142.jpg
# ./train_frame/ab/a1 143.jpg
# ./train_frame/ab/a1 144.jpg
# ./train_frame/ab/a1 15.jpg
# ./train_frame/ab/a1 16.jpg
# ./train_frame/ab/a1 164.jpg
# ./train_frame/ab/a1 165.jpg
# ./train_frame/ab/a1 166.jpg
# ./train_frame/ab/a1 167.jpg
# ./train_frame/ab/a1 168.jpg
# ./train_frame/ab/a1 169.jpg
# ./train_frame/ab/a1 17.jpg
# ./train_frame/ab/a1 18.jpg
# ./train_frame/ab/a1 186.jpg
# ./train_frame/ab/a1 187.jpg
# ./train_frame/ab/a1 188.jpg
# ./train_frame/ab/a1 19.jpg
# ...

# %%
list_ap1_3R = []
for i in range(len(test)):
        classes[predict[i]]
        list_ap1_3R.append(classes[predict[i]])

# %%
c = pd.Series(list_ap1_3R[:130], name='ap1_3R')

# %%
# print(data['ap1.3R'])
# data['a8']['n' == '0']
# data['a8']['ab' == '1']
# a = pd.Series(list_n1, name='n1')
# b = pd.Series(list_a8, name='a8')
# c = pd.Series(list_ap1_3R, name ='ap1.3R')

# %%
df = DataFrame({"n1":a, "a8":b, "ap1_3R":c})

# %%
df.head()
# Out:
#   n1  a8 ap1_3R
# 0  n   n      n
# 1  n   n     ab
# 2  n  ab     ab
# 3  n  ab     ab
# 4  n  ab     ab

# %%
df['n1'][df.n1 == 'n'] = 0
df['n1'][df.n1 == 'ab'] = 1
df['a8'][df.a8 == 'n'] = 0
df['a8'][df.a8 == 'ab'] = 1
df['ap1_3R'][df.ap1_3R == 'n'] = 0
df['ap1_3R'][df.ap1_3R == 'ab'] = 1

# %%
print(len(list_n1))
print(len(list_a8))
print(len(list_ap1_3R))
# Out:
# 130
# 428
# 263

# %%
df
# Out:
#     n1 a8 ap1_3R
# 0    0  0      0
# 1    0  0      1
# 2    0  1      1
# 3    0  1      1
# 4    0  1      1
# ..  .. ..    ...
# 125  0  0      1
# 126  0  0      1
# 127  0  0      0
# 128  0  0      1
# 129  0  0      1
#
# [130 rows x 3 columns]

# %%
df.plot.bar(figsize=(20,5), title = 'abnormal & normal')

# %%
#   0 1
# n1 130 0
# a8 42 88
# a01.3 15 115

# %%
len(df[df['n1'] == 0])
# Out:
# 130

# %%
print(len(df[df['a8'] == 0])) 
print(len(df[df['a8'] == 1]))
# Out:
# 29
# 101

# %%
print(len(df[df['ap1_3R'] == 0])) 
print(len(df[df['ap1_3R'] == 1]))
# Out:
# 15
# 115

# %%
cnt = pd.DataFrame(columns = ['0', '1'], index = ['normal', 'abnormal', 'real_patient'])
cnt.loc['normal'] = [130, 0]
cnt.loc['abnormal'] = [42, 88]
cnt.loc['real_patient'] = [15, 115]

# %%
cnt
# Out:
#                 0    1
# normal        130    0
# abnormal       42   88
# real_patient   15  115

# %%
cnt.plot.bar(figsize=(20,5), title = 'abnormal & normal')

# %%
import os
import cv2
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dropout, Activation, Dense
from keras.layers import Flatten, Convolution2D, MaxPooling2D
from keras.models import load_model

folder_path = './train_frame/'
classes = ['ab','n']
num_classes = len(classes)

image_w = 68 #원래 사이즈를 나눈값
image_h = 24

X = [] #정상, 비정상의 픽셀데이터값
Y = [] #label

for index, cla in enumerate(classes):
    label = [0 for i in range(num_classes)]
    label[index] = 1
    image_dir = folder_path + cla + '/' 
    for top, dir, f in os.walk(image_dir): # os를 사용해서 사진을 리스트로 바꾼다
        for filename in f:
#             print(image_dir+filename)
            img = cv2.imread(image_dir + filename)
            img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h / img.shape[0])
            X.append(img/256)
            Y.append(label)
X = np.array(X)
Y = np.array(Y)
print(X.shape)

model = Sequential()
model.add(Convolution2D(16, 3, 3, border_mode='same', activation='relu', input_shape=X.shape[1:]))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3, activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Convolution2D(64, 3, 3))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, Y, batch_size=16, nb_epoch=5)
model.summary()
# Out:
# (2992, 24, 68, 3)
# C:\Users\hyoji\Anaconda3\envs\hyojin\lib\site-packages\ipykernel_launcher.py:38: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(16, (3, 3), activation="relu", input_shape=(24, 68, 3..., padding="same")`
# C:\Users\hyoji\Anaconda3\envs\hyojin\lib\site-packages\ipykernel_launcher.py:42: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), activation="relu")`
# C:\Users\hyoji\Anaconda3\envs\hyojin\lib\site-packages\ipykernel_launcher.py:46: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
# C:\Users\hyoji\Anaconda3\envs\hyojin\lib\site-packages\ipykernel_launcher.py:56: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Epoch 1/5
# 2992/2992 [==============================] - 5s 2ms/step - loss: 0.2527 - acc: 0.8834A: 0s - loss: 0.2601 - acc: 0.87
# Epoch 2/5
# 2992/2992 [==============================] - 4s 1ms/step - loss: 0.0197 - acc: 0.9930
# Epoch 3/5
# ...

# %%
import cv2
import pandas as pd
import numpy as np

#test video path
video_path = './동영상/1차/1_n1.mp4' 
cap = cv2.VideoCapture(video_path)

OPENCV_OBJECT_TRACKERS = {
      "csrt": cv2.TrackerCSRT_create,
      "kcf": cv2.TrackerKCF_create,
      "boosting": cv2.TrackerBoosting_create,
      "mil": cv2.TrackerMIL_create,
      "tld": cv2.TrackerTLD_create,
      "medianflow": cv2.TrackerMedianFlow_create,
      "mosse": cv2.TrackerMOSSE_create
   }

if not cap.isOpened():
    exit()

tracker = cv2.TrackerCSRT_create()

ret, img = cap.read()
cv2.namedWindow('Window')
cv2.imshow('Window', img)

#setting ROI ROi를 설정해서 rect로 변환

x = int(img.shape[0] / 10)
y = int(img.shape[1] / 10)
print(img.shape[0],img.shape[1])
print(x,y)

out = cv2.selectROI('Window',img,fromCenter=True,showCrosshair=True)
img = img[out[1]:(out[3]+out[1]),out[0]:(out[0]+out[2])]
# img = img[(out[1]-y):(out[1]+y),(out[0]-x):(out[0]+x)]
img = cv2.resize(img,dsize=(680,240),interpolation=cv2.INTER_AREA)
cir = cv2.selectROI('Window',img, fromCenter=True, showCrosshair=True)
print(cir)
cv2.destroyWindow('Window')
# tracker 초기화
tracker.init(img, cir)

list_left = []
list_top = []

list_x=[]
list_y=[]
result_X = []
result_y = []
i = -1
j = -1
count = 0

while True:
    ret, img = cap.read()
    if count ==0 :
        cv2.imwrite("./frame%d.jpg" % count, img)
        print('Saved frame.jpg')
    
    if not ret:
        exit()
    img = img[out[1]:(out[3] + out[1]), out[0]:(out[0] + out[2])]
    img = cv2.resize(img, dsize=(680, 240), interpolation=cv2.INTER_AREA)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    success, box = tracker.update(img) # success 는 boolean , box는 데이터 값
    left, top, w, h =[int(v) for v in box]
    # cv2.circle(img,(int((left+w/2)),int((top+h/2))),int(w/2),(255,255,0),2)
    x = left + w / 2
    if x < 300 or x > 370: #중앙 x값을 300으로 지정
        cv2.imwrite("./train_frame/ab/1_n1 %d.jpg" % count, img)
#     cv2.imwrite("./frame/ab/ap-1.R %d.jpg" % count, img)
    count += 1
    #cv2.rectangle(img, pt1=(left, top),pt2 =(left+w, top+h),color = (255,255,0),thickness=2)
    print(left+w / 2)
    # print("(x,y):",left+w/2,top+h/2) #중심의 좌표값


    list_left.append(left)
    list_top.append(top)
    list_x.append(left + w / 2)
    list_y.append(top + h / 2)
    cv2.imshow('window', img)


    data = {"left좌표":list_left, "top좌표":list_top, "x좌표": list_x, "y_좌표": list_y}
    df = pd.DataFrame(data)
    # df_min_max = (df - df.min(axis=0)) / (df.max(axis=0) - df.min(axis=0))
    # df.to_csv('이석증4.2.csv', header=True)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break#그냥 꺼져 버릴 수 있음
cap.release()
cv2.destroyWindow()

# %%
def testcut(path):
    image_w = 68
    image_h = 24
    img = cv2.imread(path)
    img = cv2.resize(img, None, fx = image_w/img.shape[1], fy = image_h/img.shape[0])
    return img/256
src = []
name = []
test = []
image_dir = './test_n1/'
for file in os.listdir(image_dir):
    src.append(image_dir + file)
    name.append(file)
    test.append(testcut(image_dir+file))
src = np.array(src)
name = np.array(name)
test = np.array(test)
# print(test)

predict = model.predict_classes(test)

# %%
countlist=[]
for i in range(len(test)):
    print(name[i] + ' predict : ' + str(classes[predict[i]]))
    countlist.append(str(classes[predict[i]]))
total = countlist.count('n') + countlist.count('ab')
# Out:
# n1 176.jpg predict : n
# n1 177.jpg predict : n
# n1 178.jpg predict : n
# n1 179.jpg predict : n
# n1 180.jpg predict : n
# n1 181.jpg predict : n
# n1 182.jpg predict : n
# n1 183.jpg predict : n
# n1 184.jpg predict : n
# n1 185.jpg predict : n
# n1 186.jpg predict : n
# n1 187.jpg predict : n
# n1 188.jpg predict : n
# n1 189.jpg predict : n
# n1 190.jpg predict : n
# n1 191.jpg predict : n
# n1 192.jpg predict : n
# n1 193.jpg predict : n
# n1 194.jpg predict : n
# n1 195.jpg predict : n
# n1 196.jpg predict : n
# n1 197.jpg predict : n
# n1 198.jpg predict : n
# n1 199.jpg predict : n
# n1 200.jpg predict : n
# n1 201.jpg predict : n
# n1 202.jpg predict : n
# n1 203.jpg predict : n
# n1 204.jpg predict : n
# n1 213.jpg predict : n
# n1 214.jpg predict : n
# n1 215.jpg predict : n
# n1 216.jpg predict : n
# n1 217.jpg predict : n
# n1 218.jpg predict : n
# n1 219.jpg predict : n
# n1 220.jpg predict : n
# n1 221.jpg predict : n
# n1 222.jpg predict : n
# n1 223.jpg predict : n
# ...

# %%
f = open('result.txt', mode='wt', encoding='utf-8')
f.write('이석증 확률 : ' + str((countlist.count('ab')/total)*100) + "%")
f.close()
